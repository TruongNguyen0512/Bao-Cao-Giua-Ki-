# %%
#import library
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from keras.utils import np_utils
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
image_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)    

train_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='/content/drive/MyDrive/money-datasets/Train/',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='/content/drive/MyDrive/money-datasets/Validation/',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# Found 155 images belonging to 11 classes.
# Found 22 images belonging to 11 classes.

# %%
# X_train.shape, y_train.shape,X_test.shape,y_test.shape
train_dataset.classes
train_dataset.class_indices
# Out:
# {'100k': 0,
#  '10k': 1,
#  '1k': 2,
#  '200': 3,
#  '200k': 4,
#  '20k': 5,
#  '2k': 6,
#  '500': 7,
#  '500k': 8,
#  '50k': 9,
#  '5k': 10}

# %%
import numpy as np  #
import pandas as pd # xu ly mang
import seaborn as sns # do thi
import matplotlib.pyplot as plt # ve do hoa
from sklearn.preprocessing import StandardScaler  # xu ly du lieu , du lieu k dong deu
from sklearn.model_selection import train_test_split # chia du lieu 
from keras.layers import Dense,Activation,Dropout,BatchNormalization,LSTM #  :batch... : chuan cua ANN
from keras.models import Sequential 
from tensorflow.keras.utils import to_categorical #  de dam bao do hcinh xac cao 
from keras import callbacks #
from sklearn .metrics import  precision_score,recall_score, confusion_matrix, classification_report, accuracy_score,f1_score

# %%
# Tạo mô hinh
from keras.layers import Conv2D, MaxPooling2D
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3))) # 32 lần tích chập
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 64 lần tích chập
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 128 lần tích chập
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))

# %%
from keras.layers.convolutional import Conv2D, MaxPooling2D

from keras.layers import Dense, Activation, Flatten


model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(11,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 128)               5308544
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 5,596,971
# Trainable params: 5,596,971
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model .compile(optimizer = opt, loss ='categorical_crossentropy', metrics = ['accuracy'])
history=model.fit(train_dataset,batch_size=32,epochs=70,verbose=1,validation_data=validation_dataset)
# Out:
# Epoch 1/70
# 16/16 [==============================] - 47s 3s/step - loss: 2.4933 - accuracy: 0.1032 - val_loss: 2.4317 - val_accuracy: 0.0909
# Epoch 2/70
# 16/16 [==============================] - 31s 2s/step - loss: 2.3088 - accuracy: 0.1613 - val_loss: 2.3892 - val_accuracy: 0.0909
# Epoch 3/70
# 16/16 [==============================] - 32s 2s/step - loss: 2.1782 - accuracy: 0.2065 - val_loss: 2.5040 - val_accuracy: 0.0909
# Epoch 4/70
# 16/16 [==============================] - 32s 2s/step - loss: 1.9956 - accuracy: 0.3226 - val_loss: 2.1247 - val_accuracy: 0.3636
# Epoch 5/70
# 16/16 [==============================] - 32s 2s/step - loss: 1.8821 - accuracy: 0.3419 - val_loss: 2.1234 - val_accuracy: 0.3636
# Epoch 6/70
# 16/16 [==============================] - 33s 2s/step - loss: 1.5118 - accuracy: 0.5097 - val_loss: 2.1583 - val_accuracy: 0.3636
# Epoch 7/70
# 16/16 [==============================] - 31s 2s/step - loss: 1.3272 - accuracy: 0.5742 - val_loss: 1.9749 - val_accuracy: 0.4545
# Epoch 8/70
# 16/16 [==============================] - 35s 2s/step - loss: 1.1938 - accuracy: 0.6323 - val_loss: 1.8113 - val_accuracy: 0.4091
# Epoch 9/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.9897 - accuracy: 0.6645 - val_loss: 1.9452 - val_accuracy: 0.4545
# Epoch 10/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.6150 - accuracy: 0.8258 - val_loss: 2.5993 - val_accuracy: 0.5000
# Epoch 11/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.9733 - accuracy: 0.6774 - val_loss: 1.9846 - val_accuracy: 0.4091
# Epoch 12/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.7367 - accuracy: 0.7548 - val_loss: 2.3350 - val_accuracy: 0.5000
# Epoch 13/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.5443 - accuracy: 0.8516 - val_loss: 2.2795 - val_accuracy: 0.4091
# Epoch 14/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.3394 - accuracy: 0.9032 - val_loss: 2.9300 - val_accuracy: 0.4545
# Epoch 15/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.2888 - accuracy: 0.9161 - val_loss: 2.5524 - val_accuracy: 0.4545
# Epoch 16/70
# 16/16 [==============================] - 34s 2s/step - loss: 0.2918 - accuracy: 0.8968 - val_loss: 3.3080 - val_accuracy: 0.4091
# Epoch 17/70
# 16/16 [==============================] - 34s 2s/step - loss: 0.2222 - accuracy: 0.9419 - val_loss: 2.8776 - val_accuracy: 0.5455
# Epoch 18/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0923 - accuracy: 0.9935 - val_loss: 3.1424 - val_accuracy: 0.5455
# Epoch 19/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.0981 - accuracy: 0.9677 - val_loss: 2.7401 - val_accuracy: 0.3636
# Epoch 20/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0826 - accuracy: 0.9806 - val_loss: 3.5473 - val_accuracy: 0.5000
# Epoch 21/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0296 - accuracy: 0.9935 - val_loss: 3.5493 - val_accuracy: 0.5455
# Epoch 22/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 4.2605 - val_accuracy: 0.5455
# Epoch 23/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 3.1786 - val_accuracy: 0.5909
# Epoch 24/70
# 16/16 [==============================] - 35s 2s/step - loss: 0.0247 - accuracy: 0.9935 - val_loss: 3.0186 - val_accuracy: 0.5909
# Epoch 25/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 2.9661 - val_accuracy: 0.5455
# Epoch 26/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 3.3600 - val_accuracy: 0.5909
# Epoch 27/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0164 - accuracy: 0.9935 - val_loss: 3.9504 - val_accuracy: 0.5000
# Epoch 28/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.1192 - accuracy: 0.9677 - val_loss: 2.9209 - val_accuracy: 0.5000
# Epoch 29/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0881 - accuracy: 0.9677 - val_loss: 2.7060 - val_accuracy: 0.5909
# Epoch 30/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.1235 - accuracy: 0.9677 - val_loss: 3.5634 - val_accuracy: 0.4091
# Epoch 31/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.2124 - accuracy: 0.9548 - val_loss: 2.7961 - val_accuracy: 0.4545
# Epoch 32/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.1819 - accuracy: 0.9548 - val_loss: 3.0755 - val_accuracy: 0.5000
# Epoch 33/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.1191 - accuracy: 0.9742 - val_loss: 2.3567 - val_accuracy: 0.5000
# Epoch 34/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0670 - accuracy: 0.9806 - val_loss: 2.9925 - val_accuracy: 0.5000
# Epoch 35/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0470 - accuracy: 0.9871 - val_loss: 2.7353 - val_accuracy: 0.6364
# Epoch 36/70
# 16/16 [==============================] - 34s 2s/step - loss: 0.0310 - accuracy: 0.9871 - val_loss: 2.8577 - val_accuracy: 0.5909
# Epoch 37/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0242 - accuracy: 0.9935 - val_loss: 3.3636 - val_accuracy: 0.5000
# Epoch 38/70
# 16/16 [==============================] - 34s 2s/step - loss: 0.0209 - accuracy: 0.9935 - val_loss: 3.5168 - val_accuracy: 0.5455
# Epoch 39/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.0338 - accuracy: 0.9935 - val_loss: 2.8964 - val_accuracy: 0.5000
# Epoch 40/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 4.3701 - val_accuracy: 0.4545
# Epoch 41/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0298 - accuracy: 0.9871 - val_loss: 3.1092 - val_accuracy: 0.5909
# Epoch 42/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 3.4413 - val_accuracy: 0.5909
# Epoch 43/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.8866 - val_accuracy: 0.5909
# Epoch 44/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 3.6961 - val_accuracy: 0.5455
# Epoch 45/70
# 16/16 [==============================] - 34s 2s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 3.3994 - val_accuracy: 0.5909
# Epoch 46/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0137 - accuracy: 0.9935 - val_loss: 4.6344 - val_accuracy: 0.4545
# Epoch 47/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0171 - accuracy: 0.9935 - val_loss: 3.5693 - val_accuracy: 0.5455
# Epoch 48/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 3.8528 - val_accuracy: 0.5455
# Epoch 49/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0344 - accuracy: 0.9871 - val_loss: 3.8426 - val_accuracy: 0.5455
# Epoch 50/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0162 - accuracy: 0.9935 - val_loss: 3.1469 - val_accuracy: 0.5909
# Epoch 51/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.0241 - accuracy: 0.9935 - val_loss: 3.1213 - val_accuracy: 0.6364
# Epoch 52/70
# 16/16 [==============================] - 35s 2s/step - loss: 0.0121 - accuracy: 0.9935 - val_loss: 4.3458 - val_accuracy: 0.4091
# Epoch 53/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 3.9321 - val_accuracy: 0.4545
# Epoch 54/70
# 16/16 [==============================] - 31s 2s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 3.3058 - val_accuracy: 0.5000
# Epoch 55/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.4616 - val_accuracy: 0.5000
# Epoch 56/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.5275 - val_accuracy: 0.5000
# Epoch 57/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 3.4061 - val_accuracy: 0.5455
# Epoch 58/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0092 - accuracy: 0.9935 - val_loss: 3.5115 - val_accuracy: 0.5455
# Epoch 59/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 3.6206 - val_accuracy: 0.5455
# Epoch 60/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 3.4310 - val_accuracy: 0.6364
# Epoch 61/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0106 - accuracy: 0.9935 - val_loss: 3.4519 - val_accuracy: 0.5909
# Epoch 62/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.8455 - val_accuracy: 0.5455
# Epoch 63/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 3.8991 - val_accuracy: 0.5455
# Epoch 64/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.8168 - val_accuracy: 0.5455
# Epoch 65/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0108 - accuracy: 0.9935 - val_loss: 3.0244 - val_accuracy: 0.6364
# Epoch 66/70
# 16/16 [==============================] - 34s 2s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 3.0921 - val_accuracy: 0.6364
# Epoch 67/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 3.1615 - val_accuracy: 0.6364
# Epoch 68/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.3995 - val_accuracy: 0.5909
# Epoch 69/70
# 16/16 [==============================] - 33s 2s/step - loss: 0.0059 - accuracy: 0.9935 - val_loss: 3.6151 - val_accuracy: 0.5909
# Epoch 70/70
# 16/16 [==============================] - 32s 2s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 4.1763 - val_accuracy: 0.5000

# %%
# vẽ lại quá trình học
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()

# %%
#in sai so va do chinh xac
score = model.evaluate(validation_dataset,verbose=0)
print('Sai số : ',score[0])
print('Độ chính xác ',score[1])
# Out:
# Sai số :  4.176345348358154
# Độ chính xác  0.5

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "/content/drive/MyDrive/money-datasets/Validation/20k/2.jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq=np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("1k")
if(kq==1):
    print("10k")
if(kq==2):
    print("100k")
if(kq==3):
    print("200")
if(kq==4):
    print("2k")
if(kq==5):
    print("20k")
if(kq==6):
    print("200k")
if(kq==7):
    print("500")
if(kq==8):
    print("5k")
if(kq==9):
    print("50k")
if(kq==10):
    print("500k")
# Out:
# 1/1 [==============================] - 0s 207ms/step
# 20k

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
